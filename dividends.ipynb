# %% [markdown]
# <a href="https://colab.research.google.com/github/Gaukhar-ai/Gaukhar.Diamond.github/blob/master/dividends.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import nltk

# %%
#Load pretrained word vectors using gensim
import gensim.downloader as api

wiki_embeddings = api.load('word2vec-google-news-300')
# Out:
# [==================================================] 100.0% 1662.8/1662.8MB downloaded

# %%
wiki_embeddings['dividends']
# Out:
# array([ 2.77343750e-01,  2.49023438e-01,  1.10839844e-01,  3.55468750e-01,
#         3.98437500e-01, -2.28515625e-01,  8.54492188e-02, -1.76757812e-01,
#        -1.40625000e-01,  1.52343750e-01,  2.08984375e-01, -1.52587891e-02,
#         2.03125000e-01,  7.50000000e-01, -9.32617188e-02,  1.76757812e-01,
#         4.54101562e-02,  1.44653320e-02,  2.85156250e-01,  9.47265625e-02,
#        -1.23535156e-01, -7.08007812e-02, -1.04003906e-01,  2.86865234e-02,
#         3.18359375e-01,  1.29882812e-01,  3.07617188e-02, -8.74023438e-02,
#        -1.07421875e-01, -2.36816406e-02,  1.72851562e-01, -3.27148438e-02,
#         2.16796875e-01, -5.34667969e-02,  2.83203125e-01,  4.12597656e-02,
#         1.55029297e-02,  1.00585938e-01, -2.80761719e-03,  3.41796875e-01,
#         4.27734375e-01, -9.47265625e-02,  5.03906250e-01, -4.60937500e-01,
#         7.27539062e-02, -2.22656250e-01, -5.20019531e-02,  1.56250000e-01,
# ...

# %%
wiki_embeddings.most_similar('dividends')
# Out:
# [('dividend', 0.7800771594047546),
#  ('Dividends', 0.6747255325317383),
#  ('Dividend', 0.6369252800941467),
#  ('dividend_payouts', 0.6336338520050049),
#  ('dividend_payout', 0.621078372001648),
#  ('quarterly_dividend', 0.6020450592041016),
#  ('fully_franked_dividends', 0.5992943048477173),
#  ('distributions', 0.5578913688659668),
#  ('franked_dividends', 0.5386568307876587),
#  ('divident', 0.5367035865783691)]
